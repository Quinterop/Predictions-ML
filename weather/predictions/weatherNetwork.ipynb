# %%
import matplotlib.pyplot as plt
import numpy as np
import PIL
import tensorflow as tf
import pandas as pd

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Dense
from sklearn.metrics import f1_score

# %%
data = pd.read_csv('./NormalizedWeatherData.csv',sep=';')
data.head()
# Out:
#    Date  Type de tendance barométrique  Vitesse du vent moyen 10 mn  Humidité  \
# 0   0.0                          1.000                      0.47210   0.82828
# 1   0.0                          0.375                      0.46352   0.77778
# 2   0.0                          1.000                      0.41631   0.79798
# 3   0.0                          0.750                      0.36052   0.82828
# 4   0.0                          1.000                      0.28326   0.89899
#
#    Variation de pression en 24 heures  Rafale sur les 10 dernières minutes  \
# 0                             0.51351                              0.44258
# 1                             0.48649                              0.43137
# 2                             0.45367                              0.40336
# 3                             0.42471                              0.33613
# 4                             0.39961                              0.26050
#
#    Précipitations dans les 24 dernières heures  Température (°C)  Latitude  \
# 0                                      0.00260           0.46225       1.0
# 1                                      0.00087           0.46225       1.0
# 2                                      0.00087           0.46777       1.0
# 3                                      0.00087           0.47698       1.0
# 4                                      0.00606           0.46041       1.0
#
#    Longitude  Altitude
# 0    0.17789   0.00481
# 1    0.17789   0.00481
# 2    0.17789   0.00481
# 3    0.17789   0.00481
# 4    0.17789   0.00481
